# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv('./train.csv')

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
train_data.shape
# Out:
# (891, 12)

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_data.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
train_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_data = pd.read_csv('./train.csv', index_col='PassengerId')
train_data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
train_data[['Survived', 'Age', 'Name', 'Sex', 'Embarked']]
# Out:
#              Survived   Age  \
# PassengerId
# 1                   0  22.0
# 2                   1  38.0
# 3                   1  26.0
# 4                   1  35.0
# 5                   0  35.0
# ...               ...   ...
# 887                 0  27.0
# 888                 1  19.0
# 889                 0   NaN
# 890                 1  26.0
# 891                 0  32.0
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# 887                                      Montvila, Rev. Juozas    male
# 888                               Graham, Miss. Margaret Edith  female
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female
# 890                                      Behr, Mr. Karl Howell    male
# 891                                        Dooley, Mr. Patrick    male
#
#             Embarked
# PassengerId
# 1                  S
# 2                  C
# 3                  S
# 4                  S
# 5                  S
# ...              ...
# 887                S
# 888                S
# 889                S
# 890                C
# 891                Q
#
# [891 rows x 5 columns]

# %%
train_data[0:10]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# 6                0      0            330877   8.4583   NaN        Q
# 7                0      0             17463  51.8625   E46        S
# 8                3      1            349909  21.0750   NaN        S
# 9                0      2            347742  11.1333   NaN        S
# 10               1      0            237736  30.0708   NaN        C

# %%
train_data.index = np.arange(100, 991)

# %%
train_data.tail()
# Out:
#      Survived  Pclass                                      Name     Sex   Age  \
# 986         0       2                     Montvila, Rev. Juozas    male  27.0
# 987         1       1              Graham, Miss. Margaret Edith  female  19.0
# 988         0       3  Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 989         1       1                     Behr, Mr. Karl Howell    male  26.0
# 990         0       3                       Dooley, Mr. Patrick    male  32.0
#
#      SibSp  Parch      Ticket   Fare Cabin Embarked
# 986      0      0      211536  13.00   NaN        S
# 987      0      0      112053  30.00   B42        S
# 988      1      2  W./C. 6607  23.45   NaN        S
# 989      0      0      111369  30.00  C148        C
# 990      0      0      370376   7.75   NaN        Q

# %%
train_data.loc[986]
# Out:
# Survived                        0
# Pclass                          2
# Name        Montvila, Rev. Juozas
# Sex                          male
# Age                          27.0
# SibSp                           0
# Parch                           0
# Ticket                     211536
# Fare                         13.0
# Cabin                         NaN
# Embarked                        S
# Name: 986, dtype: object

# %%
train_data.iloc[0]
# Out:
# Survived                          0
# Pclass                            3
# Name        Braund, Mr. Owen Harris
# Sex                            male
# Age                            22.0
# SibSp                             1
# Parch                             0
# Ticket                    A/5 21171
# Fare                           7.25
# Cabin                           NaN
# Embarked                          S
# Name: 100, dtype: object

# %%
train_data.iloc[[101, 100, 200, 102], [1, 4, 5]]
# Out:
#      Pclass   Age  SibSp
# 201       3   NaN      0
# 200       3  28.0      0
# 300       3  28.0      0
# 202       1  21.0      0

# %%
class_ = train_data['Pclass'] == 1
age_ = (train_data['Age'] >=30) & (train_data['Age'] <40 )

train_data[class_ & age_]
# Out:
#      Survived  Pclass                                               Name  \
# 101         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 103         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 161         1       1                                Icard, Miss. Amelie
# 237         0       1                        Futrelle, Mr. Jacques Heath
# 315         1       1                            Newell, Miss. Madeleine
# 318         1       1                              Bazzani, Miss. Albina
# 324         1       1                       Hoyt, Mr. Frederick Maxfield
# 330         1       1       Harris, Mrs. Henry Birkhardt (Irene Wallach)
# 348         1       1                      Beckwith, Mr. Richard Leonard
# 357         1       1                               Cherry, Miss. Gladys
# 358         1       1                                   Ward, Miss. Anna
# 369         1       1                             Bissette, Miss. Amelia
# 373         0       1                              Natsch, Mr. Charles H
# 409         1       1                     Francatelli, Miss. Laura Mabel
# 418         1       1                           Wick, Miss. Mary Natalie
# 425         1       1                           Young, Miss. Marie Grice
# 432         0       1                          Graham, Mr. George Edward
# 483         1       1  Holverson, Mrs. Alexander Oskar (Mary Aline To...
# 490         1       1                         Carter, Mr. William Ernest
# 512         1       1                             Minahan, Miss. Daisy E
# 547         1       1                        Seward, Mr. Frederic Kimber
# 552         0       1                    Foreman, Mr. Benjamin Laventall
# 586         1       1    Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)
# 612         1       1                          McGough, Mr. James Robert
# 620         1       1                              Perreault, Miss. Anne
# 637         1       1                                LeRoy, Miss. Bertha
# 640         1       1                            Crosby, Miss. Harriet R
# 658         1       1             Taussig, Mrs. Emil (Tillie Mandelbaum)
# 672         1       1                   Flynn, Mr. John Irwin ("Irving")
# 677         1       1          Silvey, Mrs. William Baird (Alice Munger)
# 681         1       1  Thayer, Mrs. John Borland (Marian Longstreth M...
# 683         0       1                                Ross, Mr. John Hugo
# 704         1       1                    Homer, Mr. Harry ("Mr E Haven")
# 732         1       1                          Stahelin-Maeglin, Dr. Max
# 771         0       1                             Davidson, Mr. Thornton
# 779         1       1                 Cardeza, Mr. Thomas Drake Martinez
# 790         1       1                            Dick, Mr. Albert Adrian
# 801         1       1                   Silverthorne, Mr. Spencer Victor
# 816         1       1                      Endres, Miss. Caroline Louise
# 837         1       1                             Lesurer, Mr. Gustave J
# 841         0       1                      Cavendish, Mr. Tyrell William
# 859         1       1  Rothes, the Countess. of (Lucy Noel Martha Dye...
# 863         1       1          Carter, Mrs. William Ernest (Lucile Polk)
# 906         0       1                             Andrews, Mr. Thomas Jr
# 909         1       1     Chambers, Mrs. Norman Campbell (Bertha Griggs)
# 922         0       1                    Reuchlin, Jonkheer. John George
# 935         1       1                        Compton, Miss. Sara Rebecca
# 942         1       1                            Serepeca, Miss. Augusta
# 967         0       1               Roebling, Mr. Washington Augustus II
# 972         0       1                           Carlsson, Mr. Frans Olof
#
#         Sex   Age  SibSp  Parch      Ticket      Fare        Cabin Embarked
# 101  female  38.0      1      0    PC 17599   71.2833          C85        C
# 103  female  35.0      1      0      113803   53.1000         C123        S
# 161  female  38.0      0      0      113572   80.0000          B28      NaN
# 237    male  37.0      1      0      113803   53.1000         C123        S
# 315  female  31.0      1      0       35273  113.2750          D36        C
# 318  female  32.0      0      0       11813   76.2917          D15        C
# 324    male  38.0      1      0       19943   90.0000          C93        S
# 330  female  35.0      1      0       36973   83.4750          C83        S
# 348    male  37.0      1      1       11751   52.5542          D35        S
# 357  female  30.0      0      0      110152   86.5000          B77        S
# 358  female  35.0      0      0    PC 17755  512.3292          NaN        C
# 369  female  35.0      0      0    PC 17760  135.6333          C99        S
# 373    male  37.0      0      1    PC 17596   29.7000         C118        C
# 409  female  30.0      0      0    PC 17485   56.9292          E36        C
# 418  female  31.0      0      2       36928  164.8667           C7        S
# 425  female  36.0      0      0    PC 17760  135.6333          C32        C
# 432    male  38.0      0      1    PC 17582  153.4625          C91        S
# 483  female  35.0      1      0      113789   52.0000          NaN        S
# 490    male  36.0      1      2      113760  120.0000      B96 B98        S
# 512  female  33.0      1      0       19928   90.0000          C78        Q
# 547    male  34.0      0      0      113794   26.5500          NaN        S
# 552    male  30.0      0      0      113051   27.7500         C111        C
# 586  female  35.0      1      0       19943   90.0000          C93        S
# 612    male  36.0      0      0    PC 17473   26.2875          E25        S
# 620  female  30.0      0      0       12749   93.5000          B73        S
# 637  female  30.0      0      0    PC 17761  106.4250          NaN        C
# 640  female  36.0      0      2   WE/P 5735   71.0000          B22        S
# 658  female  39.0      1      1      110413   79.6500          E67        S
# 672    male  36.0      0      0    PC 17474   26.3875          E25        S
# 677  female  39.0      1      0       13507   55.9000          E44        S
# 681  female  39.0      1      1       17421  110.8833          C68        C
# 683    male  36.0      0      0       13049   40.1250          A10        C
# 704    male  35.0      0      0      111426   26.5500          NaN        C
# 732    male  32.0      0      0       13214   30.5000          B50        C
# 771    male  31.0      1      0  F.C. 12750   52.0000          B71        S
# 779    male  36.0      0      1    PC 17755  512.3292  B51 B53 B55        C
# 790    male  31.0      1      0       17474   57.0000          B20        S
# 801    male  35.0      0      0    PC 17475   26.2875          E24        S
# 816  female  38.0      0      0    PC 17757  227.5250          C45        C
# 837    male  35.0      0      0    PC 17755  512.3292         B101        C
# 841    male  36.0      1      0       19877   78.8500          C46        S
# 859  female  33.0      0      0      110152   86.5000          B77        S
# 863  female  36.0      1      2      113760  120.0000      B96 B98        S
# 906    male  39.0      0      0      112050    0.0000          A36        S
# 909  female  33.0      1      0      113806   53.1000           E8        S
# 922    male  38.0      0      0       19972    0.0000          NaN        S
# 935  female  39.0      1      1    PC 17756   83.1583          E49        C
# 942  female  30.0      0      0      113798   31.0000          NaN        C
# 967    male  31.0      0      0    PC 17590   50.4958          A24        S
# 972    male  33.0      0      0         695    5.0000  B51 B53 B55        S

# %%
# correlation
train_data.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
train_data.isna()
# Out:
#      Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket   Fare  \
# 100     False   False  False  False  False  False  False   False  False
# 101     False   False  False  False  False  False  False   False  False
# 102     False   False  False  False  False  False  False   False  False
# 103     False   False  False  False  False  False  False   False  False
# 104     False   False  False  False  False  False  False   False  False
# ..        ...     ...    ...    ...    ...    ...    ...     ...    ...
# 986     False   False  False  False  False  False  False   False  False
# 987     False   False  False  False  False  False  False   False  False
# 988     False   False  False  False   True  False  False   False  False
# 989     False   False  False  False  False  False  False   False  False
# 990     False   False  False  False  False  False  False   False  False
#
#      Cabin  Embarked
# 100   True     False
# 101  False     False
# 102   True     False
# 103  False     False
# 104   True     False
# ..     ...       ...
# 986   True     False
# 987  False     False
# 988   True     False
# 989  False     False
# 990   True     False
#
# [891 rows x 11 columns]

# %%
train_data['Age'].fillna(train_data['Age'].mean())
# Out:
# 100    22.000000
# 101    38.000000
# 102    26.000000
# 103    35.000000
# 104    35.000000
#          ...
# 986    27.000000
# 987    19.000000
# 988    29.699118
# 989    26.000000
# 990    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
mean1 = train_data[train_data['Survived'] == 1]['Age'].mean()
mean0 = train_data[train_data['Survived'] == 0]['Age'].mean()

print(mean1, mean0)
# Out:
# 28.343689655172415 30.62617924528302

# %%
train_data[train_data['Survived'] == 1]['Age'].fillna(mean1)
train_data[train_data['Survived'] == 0]['Age'].fillna(mean0)
# Out:
# 100    22.000000
# 104    35.000000
# 105    30.626179
# 106    54.000000
# 107     2.000000
#          ...
# 984    25.000000
# 985    39.000000
# 986    27.000000
# 988    30.626179
# 990    32.000000
# Name: Age, Length: 549, dtype: float64

# %%
train_data['Pclass'] = train_data['Pclass'].astype(str)

# %%
# One-hot encoding
pd.get_dummies(train_data, columns=['Pclass', 'Sex', 'Embarked'], drop_first=True)
# Out:
#      Survived                                               Name   Age  SibSp  \
# 100         0                            Braund, Mr. Owen Harris  22.0      1
# 101         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1
# 102         1                             Heikkinen, Miss. Laina  26.0      0
# 103         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1
# 104         0                           Allen, Mr. William Henry  35.0      0
# ..        ...                                                ...   ...    ...
# 986         0                              Montvila, Rev. Juozas  27.0      0
# 987         1                       Graham, Miss. Margaret Edith  19.0      0
# 988         0           Johnston, Miss. Catherine Helen "Carrie"   NaN      1
# 989         1                              Behr, Mr. Karl Howell  26.0      0
# 990         0                                Dooley, Mr. Patrick  32.0      0
#
#      Parch            Ticket     Fare Cabin  Pclass_2  Pclass_3  Sex_male  \
# 100      0         A/5 21171   7.2500   NaN         0         1         1
# 101      0          PC 17599  71.2833   C85         0         0         0
# 102      0  STON/O2. 3101282   7.9250   NaN         0         1         0
# 103      0            113803  53.1000  C123         0         0         0
# 104      0            373450   8.0500   NaN         0         1         1
# ..     ...               ...      ...   ...       ...       ...       ...
# 986      0            211536  13.0000   NaN         1         0         1
# 987      0            112053  30.0000   B42         0         0         0
# 988      2        W./C. 6607  23.4500   NaN         0         1         0
# 989      0            111369  30.0000  C148         0         0         1
# 990      0            370376   7.7500   NaN         0         1         1
#
#      Embarked_Q  Embarked_S
# 100           0           1
# 101           0           0
# 102           0           1
# 103           0           1
# 104           0           1
# ..          ...         ...
# 986           0           1
# 987           0           1
# 988           0           1
# 989           0           0
# 990           1           0
#
# [891 rows x 13 columns]

# %%
df = pd.read_csv('./train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
class_group = df.groupby('Pclass')
class_group

# %%
class_group.groups
# Out:
# {1: [1, 3, 6, 11, 23, 27, 30, 31, 34, 35, 52, 54, 55, 61, 62, 64, 83, 88, 92, 96, 97, 102, 110, 118, 124, 136, 137, 139, 151, 155, 166, 168, 170, 174, 177, 185, 187, 194, 195, 209, 215, 218, 224, 230, 245, 248, 252, 256, 257, 258, 262, 263, 268, 269, 270, 273, 275, 284, 290, 291, 295, 297, 298, 299, 305, 306, 307, 309, 310, 311, 318, 319, 325, 329, 331, 332, 334, 336, 337, 339, 341, 351, 356, 366, 369, 370, 373, 375, 377, 380, 383, 390, 393, 412, 430, 434, 435, 438, 445, 447, ...], 2: [9, 15, 17, 20, 21, 33, 41, 43, 53, 56, 58, 66, 70, 72, 78, 84, 98, 99, 117, 120, 122, 123, 133, 134, 135, 144, 145, 148, 149, 150, 161, 178, 181, 183, 190, 191, 193, 199, 211, 213, 217, 219, 221, 226, 228, 232, 234, 236, 237, 238, 239, 242, 247, 249, 259, 265, 272, 277, 288, 292, 303, 308, 312, 314, 316, 317, 322, 323, 327, 340, 342, 343, 344, 345, 346, 357, 361, 385, 387, 389, 397, 398, 399, 405, 407, 413, 416, 417, 418, 426, 427, 432, 437, 439, 440, 443, 446, 450, 458, 463, ...], 3: [0, 2, 4, 5, 7, 8, 10, 12, 13, 14, 16, 18, 19, 22, 24, 25, 26, 28, 29, 32, 36, 37, 38, 39, 40, 42, 44, 45, 46, 47, 48, 49, 50, 51, 57, 59, 60, 63, 65, 67, 68, 69, 71, 73, 74, 75, 76, 77, 79, 80, 81, 82, 85, 86, 87, 89, 90, 91, 93, 94, 95, 100, 101, 103, 104, 105, 106, 107, 108, 109, 111, 112, 113, 114, 115, 116, 119, 121, 125, 126, 127, 128, 129, 130, 131, 132, 138, 140, 141, 142, 143, 146, 147, 152, 153, 154, 156, 157, 158, 159, ...]}

# %%
gender_group = df.groupby('Sex')
gender_group.groups
# Out:
# {'female': [1, 2, 3, 8, 9, 10, 11, 14, 15, 18, 19, 22, 24, 25, 28, 31, 32, 38, 39, 40, 41, 43, 44, 47, 49, 52, 53, 56, 58, 61, 66, 68, 71, 79, 82, 84, 85, 88, 98, 100, 106, 109, 111, 113, 114, 119, 123, 128, 132, 133, 136, 140, 141, 142, 147, 151, 156, 161, 166, 167, 172, 177, 180, 184, 186, 190, 192, 194, 195, 198, 199, 205, 208, 211, 215, 216, 218, 229, 230, 233, 235, 237, 240, 241, 246, 247, 251, 254, 255, 256, 257, 258, 259, 264, 268, 269, 272, 274, 275, 276, ...], 'male': [0, 4, 5, 6, 7, 12, 13, 16, 17, 20, 21, 23, 26, 27, 29, 30, 33, 34, 35, 36, 37, 42, 45, 46, 48, 50, 51, 54, 55, 57, 59, 60, 62, 63, 64, 65, 67, 69, 70, 72, 73, 74, 75, 76, 77, 78, 80, 81, 83, 86, 87, 89, 90, 91, 92, 93, 94, 95, 96, 97, 99, 101, 102, 103, 104, 105, 107, 108, 110, 112, 115, 116, 117, 118, 120, 121, 122, 124, 125, 126, 127, 129, 130, 131, 134, 135, 137, 138, 139, 143, 144, 145, 146, 148, 149, 150, 152, 153, 154, 155, ...]}

# %%
class_group.count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %%
gender_group.mean()['Age']
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
class_group.mean()['Survived']
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
df.groupby('Sex').mean()['Survived']
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df.groupby(['Pclass','Sex']).mean()
# Out:
#                PassengerId  Survived        Age     SibSp     Parch  \
# Pclass Sex
# 1      female   469.212766  0.968085  34.611765  0.553191  0.457447
#        male     455.729508  0.368852  41.281386  0.311475  0.278689
# 2      female   443.105263  0.921053  28.722973  0.486842  0.605263
#        male     447.962963  0.157407  30.740707  0.342593  0.222222
# 3      female   399.729167  0.500000  21.750000  0.895833  0.798611
#        male     455.515850  0.135447  26.507589  0.498559  0.224784
#
#                      Fare
# Pclass Sex
# 1      female  106.125798
#        male     67.226127
# 2      female   21.970121
#        male     19.741782
# 3      female   16.118810
#        male     12.661633

# %%
df.groupby(['Pclass','Sex']).mean().loc[(2, 'female')]
# Out:
# PassengerId    443.105263
# Survived         0.921053
# Age             28.722973
# SibSp            0.486842
# Parch            0.605263
# Fare            21.970121
# Name: (2, female), dtype: float64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# aggregate

df.set_index(['Pclass', 'Sex']).groupby(level=[0, 1]).aggregate([np.mean, np.sum, np.max])
# Out:
#               PassengerId               Survived                 Age           \
#                      mean     sum amax      mean sum amax       mean      sum
# Pclass Sex
# 1      female  469.212766   44106  888  0.968085  91    1  34.611765  2942.00
#        male    455.729508   55599  890  0.368852  45    1  41.281386  4169.42
# 2      female  443.105263   33676  881  0.921053  70    1  28.722973  2125.50
#        male    447.962963   48380  887  0.157407  17    1  30.740707  3043.33
# 3      female  399.729167   57561  889  0.500000  72    1  21.750000  2218.50
#        male    455.515850  158064  891  0.135447  47    1  26.507589  6706.42
#
#                         SibSp               Parch                  Fare  \
#                amax      mean  sum amax      mean  sum amax        mean
# Pclass Sex
# 1      female  63.0  0.553191   52    3  0.457447   43    2  106.125798
#        male    80.0  0.311475   38    3  0.278689   34    4   67.226127
# 2      female  57.0  0.486842   37    3  0.605263   46    3   21.970121
#        male    70.0  0.342593   37    2  0.222222   24    2   19.741782
# 3      female  63.0  0.895833  129    8  0.798611  115    6   16.118810
#        male    74.0  0.498559  173    8  0.224784   78    5   12.661633
#
#
#                      sum      amax
# Pclass Sex
# 1      female  9975.8250  512.3292
#        male    8201.5875  512.3292
# 2      female  1669.7292   65.0000
#        male    2132.1125   73.5000
# 3      female  2321.1086   69.5500
#        male    4393.5865   69.5500

# %%
df.groupby('Pclass').transform(np.mean)
# Out:
#      PassengerId  Survived        Age     SibSp     Parch       Fare
# 0     439.154786  0.242363  25.140620  0.615071  0.393075  13.675550
# 1     461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2     439.154786  0.242363  25.140620  0.615071  0.393075  13.675550
# 3     461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 4     439.154786  0.242363  25.140620  0.615071  0.393075  13.675550
# ..           ...       ...        ...       ...       ...        ...
# 886   445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 887   461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 888   439.154786  0.242363  25.140620  0.615071  0.393075  13.675550
# 889   461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 890   439.154786  0.242363  25.140620  0.615071  0.393075  13.675550
#
# [891 rows x 6 columns]
